# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('HR_Data.csv')

# %%
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      22       Yes         Non-Travel       1002  Research & Development
# 1      48        No  Travel_Frequently        872                   Sales
# 2      49        No      Travel_Rarely       1018                   Sales
# 3      33        No      Travel_Rarely       1252  Research & Development
# 4      46       Yes         Non-Travel        438                   Sales
# ...   ...       ...                ...        ...                     ...
# 2738   57        No  Travel_Frequently       1449         Human Resources
# 2739   39       Yes         Non-Travel        595                   Sales
# 2740   36        No  Travel_Frequently        789         Human Resources
# 2741   43        No         Non-Travel       1163                   Sales
# 2742   23        No         Non-Travel        957  Research & Development
#
#       Education    EducationField  EmployeeCount  EmployeeNumber  \
# 0             4             Other              1            1783
# 1             3     Life Sciences              1            3918
# 2             1  Technical Degree              1             222
# 3             4         Marketing              1            2136
# 4             3             Other              1            5225
# ...         ...               ...            ...             ...
# 2738          1             Other              1            2703
# 2739          4     Life Sciences              1             332
# 2740          2  Technical Degree              1            3335
# 2741          2  Technical Degree              1            3882
# 2742          4  Technical Degree              1            2992
#
#       EnvironmentSatisfaction  ... YearsSinceLastPromotion  \
# 0                           3  ...                       5
# 1                           4  ...                       0
# 2                           4  ...                       6
# 3                           4  ...                       6
# 4                           4  ...                       5
# ...                       ...  ...                     ...
# 2738                        3  ...                       4
# 2739                        1  ...                       3
# 2740                        2  ...                       1
# 2741                        2  ...                       5
# 2742                        3  ...                       5
#
#       YearsWithCurrManager DistanceFromoffice  JobInvolvement Job Level  \
# 0                        7              Close          2 Jobs   Level 5
# 1                        6           Very Far          1 Jobs   Level 5
# 2                        5              Close          4 Jobs   Level 3
# 3                        9         Very Close          1 Jobs   Level 2
# 4                        1              Close          3 Jobs   Level 3
# ...                    ...                ...             ...       ...
# 2738                     5              Close          2 Jobs   Level 4
# 2739                     1         Very Close          2 Jobs   Level 4
# 2740                     8         Very Close          3 Jobs   Level 5
# 2741                     8         Very Close          2 Jobs   Level 4
# 2742                     9              Close          1 Jobs   Level 5
#
#       Total Working Years          Retirement   Promotion status  \
# 0                 1 Years          On service  due for promotion
# 1                19 Years  due for retirement  due for promotion
# 2                10 Years          On service  due for promotion
# 3                25 Years          On service  due for promotion
# 4                14 Years          On service  due for promotion
# ...                   ...                 ...                ...
# 2738             20 Years          On service  due for promotion
# 2739             21 Years          On service  due for promotion
# 2740             30 Years          On service  due for promotion
# 2741             10 Years  due for retirement  due for promotion
# 2742             20 Years          On service            Not due
#
#      Job satisfaction  Performance Rating
# 0              Medium        High Ratings
# 1                 Low         Low Ratings
# 2              Medium        High Ratings
# 3              Medium        High Ratings
# 4              Medium         Low Ratings
# ...               ...                 ...
# 2738              Low        High Ratings
# 2739           Medium         Low Ratings
# 2740              Low        High Ratings
# 2741           Medium         Low Ratings
# 2742             High        High Ratings
#
# [2743 rows x 38 columns]

# %%
df.head(50)
# Out:
#     Age Attrition     BusinessTravel  DailyRate              Department  \
# 0    22       Yes         Non-Travel       1002  Research & Development
# 1    48        No  Travel_Frequently        872                   Sales
# 2    49        No      Travel_Rarely       1018                   Sales
# 3    33        No      Travel_Rarely       1252  Research & Development
# 4    46       Yes         Non-Travel        438                   Sales
# 5    37        No         Non-Travel        653         Human Resources
# 6    36        No      Travel_Rarely        784  Research & Development
# 7    56       Yes  Travel_Frequently       1088         Human Resources
# 8    32        No      Travel_Rarely        339                   Sales
# 9    35        No         Non-Travel       1095         Human Resources
# 10   54       Yes      Travel_Rarely       1298         Human Resources
# 11   37        No         Non-Travel        948         Human Resources
# 12   27        No  Travel_Frequently        484                   Sales
# 13   43       Yes  Travel_Frequently        259                   Sales
# 14   43        No         Non-Travel        906         Human Resources
# 15   38        No      Travel_Rarely        232                   Sales
# 16   47       Yes      Travel_Rarely        223         Human Resources
# 17   39        No         Non-Travel        474  Research & Development
# 18   49        No      Travel_Rarely        613         Human Resources
# 19   26        No      Travel_Rarely       1349                   Sales
# 20   40        No      Travel_Rarely        581  Research & Development
# 21   45       Yes         Non-Travel       1383  Research & Development
# 22   30        No         Non-Travel       1175         Human Resources
# 23   55        No      Travel_Rarely       1342  Research & Development
# 24   31        No      Travel_Rarely        784         Human Resources
# 25   58       Yes  Travel_Frequently       1325         Human Resources
# 26   18        No      Travel_Rarely       1001  Research & Development
# 27   30        No         Non-Travel        657  Research & Development
# 28   59       Yes      Travel_Rarely        509                   Sales
# 29   38        No  Travel_Frequently        874         Human Resources
# 30   50        No         Non-Travel       1218  Research & Development
# 31   32        No         Non-Travel        512                   Sales
# 32   44       Yes  Travel_Frequently        188                   Sales
# 33   26       Yes  Travel_Frequently        422                   Sales
# 34   27        No         Non-Travel        863         Human Resources
# 35   41        No         Non-Travel        553  Research & Development
# 36   47       Yes         Non-Travel       1003                   Sales
# 37   59       Yes         Non-Travel        612                   Sales
# 38   34        No      Travel_Rarely       1242                   Sales
# 39   54        No         Non-Travel        702                   Sales
# 40   32        No      Travel_Rarely       1289         Human Resources
# 41   32        No      Travel_Rarely       1466         Human Resources
# 42   57       Yes         Non-Travel        377         Human Resources
# 43   34       Yes      Travel_Rarely        984  Research & Development
# 44   53       Yes      Travel_Rarely       1297                   Sales
# 45   45        No         Non-Travel        892                   Sales
# 46   39       Yes      Travel_Rarely       1126         Human Resources
# 47   25        No      Travel_Rarely       1043  Research & Development
# 48   41        No         Non-Travel        516         Human Resources
# 49   32        No      Travel_Rarely        859         Human Resources
#
#     Education    EducationField  EmployeeCount  EmployeeNumber  \
# 0           4             Other              1            1783
# 1           3     Life Sciences              1            3918
# 2           1  Technical Degree              1             222
# 3           4         Marketing              1            2136
# 4           3             Other              1            5225
# 5           4           Medical              1            1169
# 6           1             Other              1             880
# 7           3         Marketing              1             157
# 8           2  Technical Degree              1            1658
# 9           1           Medical              1             324
# 10          3  Technical Degree              1            5303
# 11          3  Technical Degree              1            2612
# 12          2           Medical              1             812
# 13          4           Medical              1             394
# 14          3           Medical              1            3594
# 15          1  Technical Degree              1            2639
# 16          1         Marketing              1            2188
# 17          4  Technical Degree              1            5352
# 18          2     Life Sciences              1             320
# 19          4             Other              1             168
# 20          4           Medical              1             747
# 21          1  Technical Degree              1            5471
# 22          2     Life Sciences              1            3708
# 23          4         Marketing              1            2765
# 24          1         Marketing              1            5113
# 25          2         Marketing              1            4007
# 26          3           Medical              1            1872
# 27          2         Marketing              1            5757
# 28          4         Marketing              1            3194
# 29          1         Marketing              1            3755
# 30          1           Medical              1            5626
# 31          3             Other              1            4895
# 32          4           Medical              1            4103
# 33          4             Other              1            1262
# 34          2  Technical Degree              1            2339
# 35          1     Life Sciences              1              85
# 36          4     Life Sciences              1            3822
# 37          2         Marketing              1            2654
# 38          2  Technical Degree              1            5546
# 39          4         Marketing              1            2747
# 40          1     Life Sciences              1            2859
# 41          1             Other              1             997
# 42          2         Marketing              1             229
# 43          1         Marketing              1            3265
# 44          4           Medical              1            4829
# 45          2     Life Sciences              1            3943
# 46          1     Life Sciences              1            5460
# 47          1           Medical              1            3833
# 48          1         Marketing              1            1653
# 49          4         Marketing              1              80
#
#     EnvironmentSatisfaction  ... YearsSinceLastPromotion  \
# 0                         3  ...                       5
# 1                         4  ...                       0
# 2                         4  ...                       6
# 3                         4  ...                       6
# 4                         4  ...                       5
# 5                         2  ...                       8
# 6                         2  ...                       9
# 7                         4  ...                       2
# 8                         2  ...                       7
# 9                         3  ...                       9
# 10                        1  ...                       5
# 11                        4  ...                       3
# 12                        4  ...                       3
# 13                        4  ...                       9
# 14                        4  ...                       6
# 15                        3  ...                       9
# 16                        2  ...                       2
# 17                        2  ...                       9
# 18                        3  ...                       2
# 19                        3  ...                       0
# 20                        1  ...                       9
# 21                        3  ...                       1
# 22                        4  ...                       2
# 23                        2  ...                       8
# 24                        2  ...                       7
# 25                        4  ...                       9
# 26                        3  ...                       4
# 27                        4  ...                       1
# 28                        3  ...                       9
# 29                        2  ...                       6
# 30                        3  ...                       6
# 31                        1  ...                       1
# 32                        2  ...                       1
# 33                        3  ...                       6
# 34                        1  ...                       2
# 35                        1  ...                       4
# 36                        3  ...                       0
# 37                        1  ...                       4
# 38                        1  ...                       6
# 39                        1  ...                       8
# 40                        2  ...                       2
# 41                        4  ...                       7
# 42                        4  ...                       2
# 43                        2  ...                       1
# 44                        2  ...                       0
# 45                        4  ...                       0
# 46                        2  ...                       2
# 47                        4  ...                       5
# 48                        4  ...                       8
# 49                        4  ...                       7
#
#     YearsWithCurrManager DistanceFromoffice  JobInvolvement Job Level  \
# 0                      7              Close          2 Jobs   Level 5
# 1                      6           Very Far          1 Jobs   Level 5
# 2                      5              Close          4 Jobs   Level 3
# 3                      9         Very Close          1 Jobs   Level 2
# 4                      1              Close          3 Jobs   Level 3
# 5                      4           Very Far          2 Jobs   Level 2
# 6                      4         Very Close          3 Jobs   Level 2
# 7                      7         Very Close          1 Jobs   Level 5
# 8                      9           Very Far          4 Jobs   Level 4
# 9                      1         Very Close          4 Jobs   Level 1
# 10                     0           Very Far          2 Jobs   Level 1
# 11                     0           Very Far          4 Jobs   Level 3
# 12                     0           Very Far          2 Jobs   Level 1
# 13                     2           Very Far          4 Jobs   Level 5
# 14                     9           Very Far          1 Jobs   Level 4
# 15                     1           Very Far          4 Jobs   Level 2
# 16                     3              Close          4 Jobs   Level 2
# 17                     2           Very Far          3 Jobs   Level 5
# 18                     7              Close          2 Jobs   Level 1
# 19                     6           Very Far          3 Jobs   Level 2
# 20                     0         Very Close          3 Jobs   Level 1
# 21                     0              Close          1 Jobs   Level 5
# 22                     4              Close          3 Jobs   Level 2
# 23                     1              Close          3 Jobs   Level 3
# 24                     8         Very Close          2 Jobs   Level 4
# 25                     0              Close          1 Jobs   Level 1
# 26                     2         Very Close          3 Jobs   Level 1
# 27                     2           Very Far          4 Jobs   Level 1
# 28                     8              Close          2 Jobs   Level 1
# 29                     6         Very Close          2 Jobs   Level 5
# 30                     0           Very Far          2 Jobs   Level 5
# 31                     7           Very Far          1 Jobs   Level 5
# 32                     3              Close          4 Jobs   Level 5
# 33                     0              Close          4 Jobs   Level 2
# 34                     9              Close          3 Jobs   Level 5
# 35                     8         Very Close          3 Jobs   Level 2
# 36                     8              Close          3 Jobs   Level 3
# 37                     5           Very Far          4 Jobs   Level 5
# 38                     2         Very Close          3 Jobs   Level 3
# 39                     2         Very Close          2 Jobs   Level 5
# 40                     2           Very Far          1 Jobs   Level 3
# 41                     5           Very Far          3 Jobs   Level 4
# 42                     0              Close          2 Jobs   Level 3
# 43                     7              Close          3 Jobs   Level 2
# 44                     0              Close          2 Jobs   Level 1
# 45                     3           Very Far          4 Jobs   Level 3
# 46                     7         Very Close          1 Jobs   Level 1
# 47                     1              Close          3 Jobs   Level 4
# 48                     8           Very Far          1 Jobs   Level 4
# 49                     4           Very Far          3 Jobs   Level 2
#
#     Total Working Years          Retirement   Promotion status  \
# 0               1 Years          On service  due for promotion
# 1              19 Years  due for retirement  due for promotion
# 2              10 Years          On service  due for promotion
# 3              25 Years          On service  due for promotion
# 4              14 Years          On service  due for promotion
# 5              25 Years          On service  due for promotion
# 6              21 Years          On service  due for promotion
# 7               3 Years          On service            Not due
# 8               6 Years  due for retirement  due for promotion
# 9               5 Years  due for retirement  due for promotion
# 10             17 Years          On service  due for promotion
# 11             18 Years          On service            Not due
# 12             12 Years          On service  due for promotion
# 13              5 Years          On service  due for promotion
# 14             30 Years          On service  due for promotion
# 15              9 Years  due for retirement  due for promotion
# 16             12 Years          On service            Not due
# 17             20 Years          On service            Not due
# 18              9 Years          On service  due for promotion
# 19              3 Years  due for retirement  due for promotion
# 20              1 Years  due for retirement  due for promotion
# 21             22 Years          On service            Not due
# 22             15 Years  due for retirement  due for promotion
# 23             10 Years  due for retirement            Not due
# 24             14 Years  due for retirement  due for promotion
# 25              7 Years  due for retirement            Not due
# 26              4 Years          On service            Not due
# 27             26 Years          On service  due for promotion
# 28              5 Years  due for retirement            Not due
# 29             20 Years          On service            Not due
# 30             16 Years          On service  due for promotion
# 31              3 Years          On service            Not due
# 32             17 Years          On service            Not due
# 33             13 Years          On service            Not due
# 34              6 Years  due for retirement  due for promotion
# 35             26 Years          On service  due for promotion
# 36              5 Years          On service  due for promotion
# 37             16 Years          On service            Not due
# 38             11 Years          On service            Not due
# 39             17 Years          On service  due for promotion
# 40              5 Years          On service  due for promotion
# 41              6 Years          On service  due for promotion
# 42             10 Years          On service  due for promotion
# 43             21 Years          On service  due for promotion
# 44              1 Years  due for retirement  due for promotion
# 45             30 Years          On service  due for promotion
# 46             21 Years  due for retirement  due for promotion
# 47             10 Years          On service  due for promotion
# 48             17 Years          On service  due for promotion
# 49             27 Years          On service            Not due
#
#    Job satisfaction  Performance Rating
# 0            Medium        High Ratings
# 1               Low         Low Ratings
# 2            Medium        High Ratings
# 3            Medium        High Ratings
# 4            Medium         Low Ratings
# 5               Low        High Ratings
# 6            Medium        High Ratings
# 7               Low         Low Ratings
# 8            Medium        High Ratings
# 9               Low        High Ratings
# 10              Low        High Ratings
# 11              Low        High Ratings
# 12           Medium        High Ratings
# 13           Medium        High Ratings
# 14              Low        High Ratings
# 15           Medium         Low Ratings
# 16              Low         Low Ratings
# 17              Low         Low Ratings
# 18           Medium        High Ratings
# 19           Medium        High Ratings
# 20             High        High Ratings
# 21             High        High Ratings
# 22              Low        High Ratings
# 23              Low         Low Ratings
# 24             High        High Ratings
# 25              Low         Low Ratings
# 26             High         Low Ratings
# 27           Medium         Low Ratings
# 28             High         Low Ratings
# 29              Low         Low Ratings
# 30              Low         Low Ratings
# 31           Medium        High Ratings
# 32           Medium         Low Ratings
# 33           Medium        High Ratings
# 34              Low         Low Ratings
# 35             High         Low Ratings
# 36           Medium         Low Ratings
# 37              Low         Low Ratings
# 38           Medium        High Ratings
# 39             High        High Ratings
# 40           Medium         Low Ratings
# 41              Low        High Ratings
# 42              Low        High Ratings
# 43             High         Low Ratings
# 44           Medium        High Ratings
# 45           Medium         Low Ratings
# 46             High        High Ratings
# 47           Medium        High Ratings
# 48             High         Low Ratings
# 49             High        High Ratings
#
# [50 rows x 38 columns]

# %%
df["EducationField"].head(15)
# Out:
# 0                Other
# 1        Life Sciences
# 2     Technical Degree
# 3            Marketing
# 4                Other
# 5              Medical
# 6                Other
# 7            Marketing
# 8     Technical Degree
# 9              Medical
# 10    Technical Degree
# 11    Technical Degree
# 12             Medical
# 13             Medical
# 14             Medical
# Name: EducationField, dtype: object

# %%
df.isnull().any()
# Out:
# Age                         False
# Attrition                   False
# BusinessTravel              False
# DailyRate                   False
# Department                  False
# Education                   False
# EducationField              False
# EmployeeCount               False
# EmployeeNumber              False
# EnvironmentSatisfaction     False
# Gender                      False
# HourlyRate                  False
# JobRole                     False
# JobSatisfaction             False
# MaritalStatus               False
# MonthlyIncome               False
# MonthlyRate                 False
# NumCompaniesWorked          False
# OverTime                    False
# PercentSalaryHike           False
# PerformanceRating           False
# RelationshipSatisfaction    False
# StandardHours               False
# StockOptionLevel            False
# TrainingTimesLastYear       False
# WorkLifeBalance             False
# YearsAtCompany              False
# YearsInCurrentRole          False
# YearsSinceLastPromotion     False
# YearsWithCurrManager        False
# DistanceFromoffice          False
# JobInvolvement              False
# Job Level                   False
# Total Working Years         False
# Retirement                  False
# Promotion status            False
# Job satisfaction            False
# Performance Rating          False
# dtype: bool

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2743 entries, 0 to 2742
# Data columns (total 38 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       2743 non-null   int64
#  1   Attrition                 2743 non-null   object
#  2   BusinessTravel            2743 non-null   object
#  3   DailyRate                 2743 non-null   int64
#  4   Department                2743 non-null   object
#  5   Education                 2743 non-null   int64
#  6   EducationField            2743 non-null   object
#  7   EmployeeCount             2743 non-null   int64
#  8   EmployeeNumber            2743 non-null   int64
#  9   EnvironmentSatisfaction   2743 non-null   int64
#  10  Gender                    2743 non-null   object
#  11  HourlyRate                2743 non-null   int64
#  12  JobRole                   2743 non-null   object
#  13  JobSatisfaction           2743 non-null   int64
#  14  MaritalStatus             2743 non-null   object
#  15  MonthlyIncome             2743 non-null   int64
#  16  MonthlyRate               2743 non-null   int64
#  17  NumCompaniesWorked        2743 non-null   int64
#  18  OverTime                  2743 non-null   object
#  19  PercentSalaryHike         2743 non-null   int64
#  20  PerformanceRating         2743 non-null   int64
#  21  RelationshipSatisfaction  2743 non-null   int64
#  22  StandardHours             2743 non-null   int64
#  23  StockOptionLevel          2743 non-null   int64
#  24  TrainingTimesLastYear     2743 non-null   int64
#  25  WorkLifeBalance           2743 non-null   int64
#  26  YearsAtCompany            2743 non-null   int64
#  27  YearsInCurrentRole        2743 non-null   int64
#  28  YearsSinceLastPromotion   2743 non-null   int64
#  29  YearsWithCurrManager      2743 non-null   int64
#  30  DistanceFromoffice        2743 non-null   object
#  31  JobInvolvement            2743 non-null   object
#  32  Job Level                 2743 non-null   object
#  33  Total Working Years       2743 non-null   object
#  34  Retirement                2743 non-null   object
#  35  Promotion status          2743 non-null   object
#  36  Job satisfaction          2743 non-null   object
#  37  Performance Rating        2743 non-null   object
# dtypes: int64(22), object(16)
# memory usage: 814.5+ KB

# %%
df.describe()
# Out:
#                Age    DailyRate    Education  EmployeeCount  EmployeeNumber  \
# count  2743.000000  2743.000000  2743.000000         2743.0     2743.000000
# mean     38.682100   806.507838     2.510026            1.0     2954.429092
# std      12.018961   398.824442     1.113454            0.0     1740.577815
# min      18.000000   100.000000     1.000000            1.0        7.000000
# 25%      29.000000   466.000000     2.000000            1.0     1441.500000
# 50%      39.000000   804.000000     2.000000            1.0     2923.000000
# 75%      49.000000  1140.000000     4.000000            1.0     4495.500000
# max      59.000000  1498.000000     4.000000            1.0     6000.000000
#
#        EnvironmentSatisfaction   HourlyRate  JobSatisfaction  MonthlyIncome  \
# count              2743.000000  2743.000000      2743.000000    2743.000000
# mean                  2.493985    64.610645         2.495078   10963.245352
# std                   1.103282    20.379641         1.115124    5152.176213
# min                   1.000000    30.000000         1.000000    2002.000000
# 25%                   2.000000    47.000000         1.000000    6617.500000
# 50%                   2.000000    65.000000         3.000000   10918.000000
# 75%                   3.000000    82.000000         3.000000   15327.500000
# max                   4.000000    99.000000         4.000000   19997.000000
#
#         MonthlyRate  ...  PerformanceRating  RelationshipSatisfaction  \
# count   2743.000000  ...        2743.000000               2743.000000
# mean   15979.907401  ...           3.495808                  2.491433
# std     7980.305411  ...           0.500074                  1.126815
# min     2003.000000  ...           3.000000                  1.000000
# 25%     9108.500000  ...           3.000000                  1.000000
# 50%    15937.000000  ...           3.000000                  3.000000
# 75%    22835.500000  ...           4.000000                  3.000000
# max    29988.000000  ...           4.000000                  4.000000
#
#        StandardHours  StockOptionLevel  TrainingTimesLastYear  \
# count         2743.0       2743.000000            2743.000000
# mean            80.0          1.506380               2.440758
# std              0.0          1.106911               1.716837
# min             80.0          0.000000               0.000000
# 25%             80.0          1.000000               1.000000
# 50%             80.0          1.000000               2.000000
# 75%             80.0          2.000000               4.000000
# max             80.0          3.000000               5.000000
#
#        WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# count      2743.000000     2743.000000         2743.000000
# mean          2.505286        9.562523            4.529712
# std           1.117736        5.806038            2.890370
# min           1.000000        0.000000            0.000000
# 25%           2.000000        4.000000            2.000000
# 50%           3.000000       10.000000            5.000000
# 75%           4.000000       15.000000            7.000000
# max           4.000000       19.000000            9.000000
#
#        YearsSinceLastPromotion  YearsWithCurrManager
# count              2743.000000           2743.000000
# mean                  4.477579              4.475027
# std                   2.873606              2.898353
# min                   0.000000              0.000000
# 25%                   2.000000              2.000000
# 50%                   4.000000              4.000000
# 75%                   7.000000              7.000000
# max                   9.000000              9.000000
#
# [8 rows x 22 columns]

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'Education', 'EducationField', 'EmployeeCount', 'EmployeeNumber',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobRole',
#        'JobSatisfaction', 'MaritalStatus', 'MonthlyIncome', 'MonthlyRate',
#        'NumCompaniesWorked', 'OverTime', 'PercentSalaryHike',
#        'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours',
#        'StockOptionLevel', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager', 'DistanceFromoffice', 'JobInvolvement',
#        'Job Level', 'Total Working Years', 'Retirement', 'Promotion status',
#        'Job satisfaction', 'Performance Rating'],
#       dtype='object')

# %%
df["Attrition"].value_counts()
# Out:
# Attrition
# No     1916
# Yes     827
# Name: count, dtype: int64

# %%
df["Attrition"].dtype
# Out:
# dtype('O')

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   22       Yes         Non-Travel       1002  Research & Development
# 1   48        No  Travel_Frequently        872                   Sales
# 2   49        No      Travel_Rarely       1018                   Sales
# 3   33        No      Travel_Rarely       1252  Research & Development
# 4   46       Yes         Non-Travel        438                   Sales
#
#    Education    EducationField  EmployeeCount  EmployeeNumber  \
# 0          4             Other              1            1783
# 1          3     Life Sciences              1            3918
# 2          1  Technical Degree              1             222
# 3          4         Marketing              1            2136
# 4          3             Other              1            5225
#
#    EnvironmentSatisfaction  ... YearsSinceLastPromotion  YearsWithCurrManager  \
# 0                        3  ...                       5                     7
# 1                        4  ...                       0                     6
# 2                        4  ...                       6                     5
# 3                        4  ...                       6                     9
# 4                        4  ...                       5                     1
#
#   DistanceFromoffice  JobInvolvement Job Level  Total Working Years  \
# 0              Close          2 Jobs   Level 5              1 Years
# 1           Very Far          1 Jobs   Level 5             19 Years
# 2              Close          4 Jobs   Level 3             10 Years
# 3         Very Close          1 Jobs   Level 2             25 Years
# 4              Close          3 Jobs   Level 3             14 Years
#
#            Retirement   Promotion status Job satisfaction  Performance Rating
# 0          On service  due for promotion           Medium        High Ratings
# 1  due for retirement  due for promotion              Low         Low Ratings
# 2          On service  due for promotion           Medium        High Ratings
# 3          On service  due for promotion           Medium        High Ratings
# 4          On service  due for promotion           Medium         Low Ratings
#
# [5 rows x 38 columns]

# %%
df.describe(include = 'O')
# Out:
#        Attrition BusinessTravel              Department EducationField Gender  \
# count       2743           2743                    2743           2743   2743
# unique         2              3                       3              5      2
# top           No  Travel_Rarely  Research & Development        Medical   Male
# freq        1916           1324                     969            581   1834
#
#              JobRole MaritalStatus OverTime DistanceFromoffice JobInvolvement  \
# count           2743          2743     2743               2743           2743
# unique             8             3        2                  3              4
# top     HR Executive       Married       No              Close         2 Jobs
# freq             365           942     1401                960            702
#
#        Job Level Total Working Years  Retirement   Promotion status  \
# count       2743                2743        2743               2743
# unique         5                  30           2                  2
# top      Level 2            21 Years  On service  due for promotion
# freq         587                 107        2020               1995
#
#        Job satisfaction Performance Rating
# count              2743               2743
# unique                3                  2
# top              Medium       High Ratings
# freq               1087               1381

# %%
df.head(5)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   22       Yes         Non-Travel       1002  Research & Development
# 1   48        No  Travel_Frequently        872                   Sales
# 2   49        No      Travel_Rarely       1018                   Sales
# 3   33        No      Travel_Rarely       1252  Research & Development
# 4   46       Yes         Non-Travel        438                   Sales
#
#    Education    EducationField  EmployeeCount  EmployeeNumber  \
# 0          4             Other              1            1783
# 1          3     Life Sciences              1            3918
# 2          1  Technical Degree              1             222
# 3          4         Marketing              1            2136
# 4          3             Other              1            5225
#
#    EnvironmentSatisfaction  ... YearsSinceLastPromotion  YearsWithCurrManager  \
# 0                        3  ...                       5                     7
# 1                        4  ...                       0                     6
# 2                        4  ...                       6                     5
# 3                        4  ...                       6                     9
# 4                        4  ...                       5                     1
#
#   DistanceFromoffice  JobInvolvement Job Level  Total Working Years  \
# 0              Close          2 Jobs   Level 5              1 Years
# 1           Very Far          1 Jobs   Level 5             19 Years
# 2              Close          4 Jobs   Level 3             10 Years
# 3         Very Close          1 Jobs   Level 2             25 Years
# 4              Close          3 Jobs   Level 3             14 Years
#
#            Retirement   Promotion status Job satisfaction  Performance Rating
# 0          On service  due for promotion           Medium        High Ratings
# 1  due for retirement  due for promotion              Low         Low Ratings
# 2          On service  due for promotion           Medium        High Ratings
# 3          On service  due for promotion           Medium        High Ratings
# 4          On service  due for promotion           Medium         Low Ratings
#
# [5 rows x 38 columns]

# %%
df["EducationField"].value_counts()
# Out:
# EducationField
# Medical             581
# Technical Degree    580
# Marketing           572
# Life Sciences       539
# Other               471
# Name: count, dtype: int64

# %%
df["Department"].value_counts()
# Out:
# Department
# Research & Development    969
# Human Resources           913
# Sales                     861
# Name: count, dtype: int64

# %%
df.head(5)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   22       Yes         Non-Travel       1002  Research & Development
# 1   48        No  Travel_Frequently        872                   Sales
# 2   49        No      Travel_Rarely       1018                   Sales
# 3   33        No      Travel_Rarely       1252  Research & Development
# 4   46       Yes         Non-Travel        438                   Sales
#
#    Education    EducationField  EmployeeCount  EmployeeNumber  \
# 0          4             Other              1            1783
# 1          3     Life Sciences              1            3918
# 2          1  Technical Degree              1             222
# 3          4         Marketing              1            2136
# 4          3             Other              1            5225
#
#    EnvironmentSatisfaction  ... YearsSinceLastPromotion  YearsWithCurrManager  \
# 0                        3  ...                       5                     7
# 1                        4  ...                       0                     6
# 2                        4  ...                       6                     5
# 3                        4  ...                       6                     9
# 4                        4  ...                       5                     1
#
#   DistanceFromoffice  JobInvolvement Job Level  Total Working Years  \
# 0              Close          2 Jobs   Level 5              1 Years
# 1           Very Far          1 Jobs   Level 5             19 Years
# 2              Close          4 Jobs   Level 3             10 Years
# 3         Very Close          1 Jobs   Level 2             25 Years
# 4              Close          3 Jobs   Level 3             14 Years
#
#            Retirement   Promotion status Job satisfaction  Performance Rating
# 0          On service  due for promotion           Medium        High Ratings
# 1  due for retirement  due for promotion              Low         Low Ratings
# 2          On service  due for promotion           Medium        High Ratings
# 3          On service  due for promotion           Medium        High Ratings
# 4          On service  due for promotion           Medium         Low Ratings
#
# [5 rows x 38 columns]

# %%
sns.countplot(x=df.Attrition,hue=df.Attrition)
# Out:
# <Axes: xlabel='Attrition', ylabel='count'>

# %%
sns.countplot(hue=df.BusinessTravel, x=df.Attrition)
plt.show()

# %%
sns.countplot(hue=df.EducationField, x=df.Attrition)
plt.show()

# %%
sns.countplot(hue=df.Department, x=df.Attrition)
plt.show()

# %%
sns.countplot(hue=df.Gender, x=df.Attrition)
plt.show()

# %%
sns.countplot(hue=df.OverTime, x=df.Attrition)
plt.show()

# %%
sns.countplot(hue= df.JobRole, x=df.Attrition)
plt.show()

# %%
df["Age"].hist(bins=70)
plt.title("Age Distribution of employees")
plt.xlabel("Age")
plt.ylabel("Attrition")
plt.show()

# %%
sns.histplot(hue= df.Attrition, x=df.Age)
plt.show()

# %%
sns.histplot(hue=df.Attrition, x=df.DistanceFromoffice)
plt.show()

# %%
sns.histplot(hue=df.Attrition, x=df.MonthlyIncome)
plt.show()

# %%
sns.histplot(hue=df.Attrition, x=df.MaritalStatus)
plt.show()

# %%
sns.countplot(hue=df.Attrition, x=df.PercentSalaryHike)
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.countplot(hue=df.Attrition, x=df.YearsAtCompany)
plt.show()

# %%
sns.countplot(hue=df.Attrition, x=df.EnvironmentSatisfaction)
plt.show()

# %%
sns.countplot(hue=df.Attrition, x=df.JobInvolvement)
plt.show()

# %%
sns.countplot(hue=df.Attrition, x=df.StockOptionLevel)
plt.show()

# %%
sns.countplot(hue=df.Attrition, x=df.PerformanceRating)
plt.show()

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# YearsInCurrentRole          0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# DistanceFromoffice          0
# JobInvolvement              0
# Job Level                   0
# Total Working Years         0
# Retirement                  0
# Promotion status            0
# Job satisfaction            0
# Performance Rating          0
# dtype: int64

# %%
df["OverTime"]
# Out:
# 0        No
# 1        No
# 2       Yes
# 3        No
# 4        No
#        ...
# 2738    Yes
# 2739    Yes
# 2740    Yes
# 2741     No
# 2742     No
# Name: OverTime, Length: 2743, dtype: object

# %%
df["MaritalStatus"]= df["MaritalStatus"].map({"Yes": 1, "No" :0})

# %%
df["Gender"]= df["Gender"].map({"Male": 1, "Female" :2})

# %%
df["JobRole"]= df["JobRole"].map({"Laboratory Technician": 8, "Sales Executive" :7, "Research Scientist": 6, "Sales Representive" :5, "Human Resources": 4, "Manufacturing Director" :3, "Healthcare Representative": 2, "Manager" :1, "Research Director" :0})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2743 entries, 0 to 2742
# Data columns (total 38 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       2743 non-null   int64
#  1   Attrition                 2743 non-null   object
#  2   BusinessTravel            2743 non-null   object
#  3   DailyRate                 2743 non-null   int64
#  4   Department                2743 non-null   object
#  5   Education                 2743 non-null   int64
#  6   EducationField            2743 non-null   object
#  7   EmployeeCount             2743 non-null   int64
#  8   EmployeeNumber            2743 non-null   int64
#  9   EnvironmentSatisfaction   2743 non-null   int64
#  10  Gender                    2743 non-null   int64
#  11  HourlyRate                2743 non-null   int64
#  12  JobRole                   1018 non-null   float64
#  13  JobSatisfaction           2743 non-null   int64
#  14  MaritalStatus             0 non-null      float64
#  15  MonthlyIncome             2743 non-null   int64
#  16  MonthlyRate               2743 non-null   int64
#  17  NumCompaniesWorked        2743 non-null   int64
#  18  OverTime                  2743 non-null   object
#  19  PercentSalaryHike         2743 non-null   int64
#  20  PerformanceRating         2743 non-null   int64
#  21  RelationshipSatisfaction  2743 non-null   int64
#  22  StandardHours             2743 non-null   int64
#  23  StockOptionLevel          2743 non-null   int64
#  24  TrainingTimesLastYear     2743 non-null   int64
#  25  WorkLifeBalance           2743 non-null   int64
#  26  YearsAtCompany            2743 non-null   int64
#  27  YearsInCurrentRole        2743 non-null   int64
#  28  YearsSinceLastPromotion   2743 non-null   int64
#  29  YearsWithCurrManager      2743 non-null   int64
#  30  DistanceFromoffice        2743 non-null   object
#  31  JobInvolvement            2743 non-null   object
#  32  Job Level                 2743 non-null   object
#  33  Total Working Years       2743 non-null   object
#  34  Retirement                2743 non-null   object
#  35  Promotion status          2743 non-null   object
#  36  Job satisfaction          2743 non-null   object
#  37  Performance Rating        2743 non-null   object
# dtypes: float64(2), int64(23), object(13)
# memory usage: 814.5+ KB

# %%
df.drop(["EmployeeCount", "EmployeeNumber", "StandardHours", "MaritalStatus"], axis = 1, inplace = True)
df.dropna(inplace = True)

# %%
x = df.drop(["Attrition"],axis = 1)
y = df["Attrition"]

# %%
# !pip install -U imbalanced-learn
# Out:
# Requirement already satisfied: imbalanced-learn in c:\programdata\anaconda3\lib\site-packages (0.14.1)
# Requirement already satisfied: numpy<3,>=1.25.2 in c:\programdata\anaconda3\lib\site-packages (from imbalanced-learn) (2.3.5)
# Requirement already satisfied: scipy<2,>=1.11.4 in c:\programdata\anaconda3\lib\site-packages (from imbalanced-learn) (1.16.3)
# Requirement already satisfied: scikit-learn<2,>=1.4.2 in c:\programdata\anaconda3\lib\site-packages (from imbalanced-learn) (1.7.2)
# Requirement already satisfied: sklearn-compat<0.2,>=0.1.5 in c:\programdata\anaconda3\lib\site-packages (from imbalanced-learn) (0.1.5)
# Requirement already satisfied: joblib<2,>=1.2.0 in c:\programdata\anaconda3\lib\site-packages (from imbalanced-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from imbalanced-learn) (3.5.0)

# %%
x = pd.get_dummies(x, drop_first=True)

# %%
from sklearn.preprocessing import LabelEncoder
y = LabelEncoder().fit_transform(y)

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state=42
)

# %%
from imblearn.over_sampling import SMOTE
from collections import Counter

print("Before SMOTE:", Counter(y_train))

sm = SMOTE(random_state=42)
x_train, y_train = sm.fit_resample(x_train, y_train)

print("After SMOTE:", Counter(y_train))
# Out:
# Before SMOTE: Counter({np.int64(0): 561, np.int64(1): 253})
# After SMOTE: Counter({np.int64(1): 561, np.int64(0): 561})

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression

lr_model = LogisticRegression(max_iter=3000)
lr_model.fit(x_train, y_train)

y_pred_lr = lr_model.predict(x_test)

# %%
from sklearn.ensemble import RandomForestClassifier

rf_model = RandomForestClassifier(random_state=42)
rf_model.fit(x_train, y_train)

y_pred_rf = rf_model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

print("===== LOGISTIC REGRESSION =====")
print("Accuracy:", accuracy_score(y_test, y_pred_lr))
print(confusion_matrix(y_test, y_pred_lr))
print(classification_report(y_test, y_pred_lr))

print("\n===== RANDOM FOREST =====")
print("Accuracy:", accuracy_score(y_test, y_pred_rf))
print(confusion_matrix(y_test, y_pred_rf))
print(classification_report(y_test, y_pred_rf))
# Out:
# ===== LOGISTIC REGRESSION =====
# Accuracy: 0.5686274509803921
# [[104  31]
#  [ 57  12]]
#               precision    recall  f1-score   support
#
#            0       0.65      0.77      0.70       135
#            1       0.28      0.17      0.21        69
#
#     accuracy                           0.57       204
#    macro avg       0.46      0.47      0.46       204
# weighted avg       0.52      0.57      0.54       204
#
#
# ===== RANDOM FOREST =====
# Accuracy: 0.6176470588235294
# [[122  13]
#  [ 65   4]]
#               precision    recall  f1-score   support
#
#            0       0.65      0.90      0.76       135
#            1       0.24      0.06      0.09        69
#
#     accuracy                           0.62       204
#    macro avg       0.44      0.48      0.43       204
# weighted avg       0.51      0.62      0.53       204

# %%
importance = pd.DataFrame({
    'Feature': x.columns,
    'Importance': rf_model.feature_importances_
}).sort_values(by='Importance', ascending=False)

importance.head(10)
# Out:
#                  Feature  Importance
# 9            MonthlyRate    0.053355
# 8          MonthlyIncome    0.051130
# 5             HourlyRate    0.042755
# 1              DailyRate    0.042616
# 0                    Age    0.041512
# 6                JobRole    0.036293
# 17        YearsAtCompany    0.035076
# 10    NumCompaniesWorked    0.034370
# 20  YearsWithCurrManager    0.032166
# 11     PercentSalaryHike    0.031921

# %%
importance.head(10).plot(
    kind='barh', x='Feature', y='Importance', figsize=(8,5)
)
plt.title("Top Important Features")
plt.show()

# %%
from sklearn.metrics import roc_curve, auc

y_prob = rf_model.predict_proba(x_test)[:,1]

fpr, tpr, _ = roc_curve(y_test, y_prob)
roc_auc = auc(fpr, tpr)

plt.plot(fpr, tpr)
plt.title(f"ROC Curve (AUC = {roc_auc:.2f})")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.show()
